# %%
import gymnasium as gym
import torch
import torch.optim as optim
import numpy as np
import time

import matplotlib.pyplot as plt

import my_package
from my_package.core.AC_v3 import AC_agent

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

gamma = 0.99

lr_actor = 1e-4
lr_critic = 1e-4
tau = 0.001

buffer_size = 1000000
batch_size = 256

max_episodes = 1000
data_window = 10


env_name = 'ShipRovCont-v0'
Options = {
    'generate_random_ship':             True,
    'workspace_safe_distance':          2,
    'ship_scale_factor':                0.9,
    'segments_lenght':                  0.25,
    'frame_per_step':                   10,
    'init_pose':                        None,
    'agent_radius':                     0.1,
    'v_surge_max':                      0.1,
    'v_sway_max' :                      0.05,
    'yaw_rel_max':                      np.pi/4,
    'frontal_safe_distance':            0.5,
    'lidar_params':                     {'n_beams': 10, 'max_range': 2.0, 'FoV': np.pi/2},
    'draw_lidar':                       True,
    'max_steps':                        2000
}	

""" Init env """
env = gym.make(env_name, Options=Options)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]

""" Init AC agent """
agent = AC_agent(
    state_size=state_dim,
    action_size=action_dim,
    gamma=gamma,
    tau=tau,
    lr_actor=lr_actor,
    lr_critic=lr_critic,
    device=device,
    noise_type='param',
    buffer_size=buffer_size,
    batch_size=batch_size,
    max_episodes=max_episodes,
    desired_distance=0.7,
    n_learn=8,
)

""" Data collect variables """
total_rewards = np.zeros(max_episodes)
noise_history = np.zeros(max_episodes)
len_episodes = np.zeros(max_episodes)
critic_loss_history = []
actor_loss_history = []
coverage_per_ep = np.zeros(max_episodes)

# %%
start_time = time.time()

for episode in range(max_episodes):
    state, info = env.reset()
    agent.reset(episode)
    done = False
    
    while not done:
        action = agent.act(state)
        next_state, reward, terminated, truncated, info = env.step(action)
        agent.step(state, action, reward, next_state, terminated)

        total_rewards[episode] += reward
        len_episodes[episode] += 1
        state = next_state
        done = terminated or truncated

    coverage_per_ep[episode] = info['coverage']
    
    if episode % data_window == 0 and episode != 0:
        ma_reward = np.mean(total_rewards[episode-data_window:episode])
        ma_coverage = np.mean(coverage_per_ep[episode-data_window:episode])
        print(f"Ep {episode}/{max_episodes}, MA Reward: {ma_reward:.2f}, MA Coverage: {ma_coverage:.1f} %")

env.close()

total_time_seconds = time.time() - start_time
hours = int(total_time_seconds // 3600)
minutes = int((total_time_seconds % 3600) // 60)
seconds = int(total_time_seconds % 60)
print(f"Training finito in: {hours} ore {minutes} minuti e {seconds} secondi")
# Out:
# Ep 10/1000, MA Reward: -26.47, MA Coverage: 2.6 %
# Ep 20/1000, MA Reward: -24.80, MA Coverage: 2.0 %
# Ep 30/1000, MA Reward: -26.50, MA Coverage: 1.3 %
# Ep 40/1000, MA Reward: -22.70, MA Coverage: 16.3 %
# Ep 50/1000, MA Reward: -20.32, MA Coverage: 22.4 %
# Ep 60/1000, MA Reward: -18.85, MA Coverage: 19.1 %
# Ep 70/1000, MA Reward: -24.27, MA Coverage: 21.7 %
# Ep 80/1000, MA Reward: -16.33, MA Coverage: 36.3 %
# Ep 90/1000, MA Reward: -17.43, MA Coverage: 25.7 %
# Ep 100/1000, MA Reward: -18.18, MA Coverage: 31.1 %
# Ep 110/1000, MA Reward: -15.84, MA Coverage: 35.9 %
# Ep 120/1000, MA Reward: 7.04, MA Coverage: 68.0 %
# Ep 590/1000, MA Reward: 4.50, MA Coverage: 42.0 %
# Ep 600/1000, MA Reward: 0.22, MA Coverage: 40.7 %
# Ep 610/1000, MA Reward: -14.13, MA Coverage: 27.0 %
# Ep 620/1000, MA Reward: -7.42, MA Coverage: 37.4 %
# Ep 630/1000, MA Reward: 15.88, MA Coverage: 65.2 %
# Ep 640/1000, MA Reward: 41.68, MA Coverage: 67.4 %
# Ep 650/1000, MA Reward: 75.24, MA Coverage: 72.4 %
# Ep 660/1000, MA Reward: 50.27, MA Coverage: 69.3 %
# Ep 670/1000, MA Reward: 80.78, MA Coverage: 80.9 %
# Ep 680/1000, MA Reward: 93.29, MA Coverage: 87.2 %
# Ep 690/1000, MA Reward: 77.62, MA Coverage: 73.3 %
# Ep 700/1000, MA Reward: 105.49, MA Coverage: 85.9 %
# Ep 710/1000, MA Reward: 119.28, MA Coverage: 90.0 %
# Ep 720/1000, MA Reward: 119.45, MA Coverage: 95.2 %
# Ep 730/1000, MA Reward: 121.92, MA Coverage: 93.7 %
# Ep 740/1000, MA Reward: 136.86, MA Coverage: 100.0 %
# Ep 750/1000, MA Reward: 124.26, MA Coverage: 95.7 %
# Ep 760/1000, MA Reward: 113.07, MA Coverage: 93.3 %
# Ep 770/1000, MA Reward: 126.12, MA Coverage: 98.5 %
# Ep 780/1000, MA Reward: 122.62, MA Coverage: 93.0 %
# Ep 790/1000, MA Reward: 109.91, MA Coverage: 88.5 %
# Ep 800/1000, MA Reward: 140.48, MA Coverage: 100.0 %
# Ep 810/1000, MA Reward: 123.55, MA Coverage: 90.0 %
# Ep 820/1000, MA Reward: 124.09, MA Coverage: 90.0 %
# Ep 830/1000, MA Reward: 124.02, MA Coverage: 90.0 %
# Ep 840/1000, MA Reward: 127.58, MA Coverage: 97.8 %
# Ep 850/1000, MA Reward: 140.79, MA Coverage: 100.0 %
# Ep 860/1000, MA Reward: 126.92, MA Coverage: 97.2 %
# Ep 870/1000, MA Reward: 141.17, MA Coverage: 100.0 %
# Ep 880/1000, MA Reward: 126.14, MA Coverage: 94.3 %
# Ep 890/1000, MA Reward: 126.18, MA Coverage: 93.7 %
# Ep 900/1000, MA Reward: 141.32, MA Coverage: 100.0 %
# Ep 910/1000, MA Reward: 141.39, MA Coverage: 100.0 %
# Ep 920/1000, MA Reward: 141.11, MA Coverage: 100.0 %
# Ep 930/1000, MA Reward: 128.13, MA Coverage: 98.9 %
# Ep 940/1000, MA Reward: 126.59, MA Coverage: 94.3 %
# Ep 950/1000, MA Reward: 79.41, MA Coverage: 72.8 %
# Ep 960/1000, MA Reward: 81.49, MA Coverage: 77.6 %
# Ep 970/1000, MA Reward: 107.71, MA Coverage: 80.0 %
# Ep 980/1000, MA Reward: 126.66, MA Coverage: 95.0 %
# Ep 990/1000, MA Reward: 124.69, MA Coverage: 90.0 %
# Training finito in: 6 ore 6 minuti e 27 secondi

# %%
""" Plot rewards """
window_size = 50
ma_reward = np.convolve(total_rewards, np.ones(window_size) / window_size, mode='valid')
plt.figure(figsize=(10, 6))
plt.scatter(np.arange(len(total_rewards)), total_rewards)
plt.plot(np.arange(window_size - 1, len(total_rewards)), ma_reward, color='red', label=f'Moving Average (Window={window_size})', linewidth=2)
plt.title('Total Reward and Moving Average Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.legend()
plt.grid(True)
plt.show()


""" Plot coverage """
window_size = 50
ma_coverage = np.convolve(coverage_per_ep, np.ones(window_size) / window_size, mode='valid')
plt.figure(figsize=(10, 6))
plt.scatter(np.arange(len(coverage_per_ep)), coverage_per_ep)
plt.plot(np.arange(window_size - 1, len(coverage_per_ep)), ma_coverage, color='red', label=f'Moving Average (Window={window_size})', linewidth=2)
plt.title('Coverage and Moving Average Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Coverage %')
plt.legend()
plt.grid(True)
plt.show()

""" Plot episode duration """
window_size = 50
ma_steps = np.convolve(len_episodes, np.ones(window_size) / window_size, mode='valid')
plt.figure(figsize=(10, 6))
plt.scatter(np.arange(len(len_episodes)), len_episodes)
plt.plot(np.arange(window_size - 1, max_episodes), ma_steps, color='red', label=f'Moving Average (Window={window_size})', linewidth=2)
plt.title('Steps per Episode and Moving Average Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Total steps')
plt.legend()
plt.grid(True)
plt.show()

# %%
Options['v_surge_max' ] = 0.1
env = gym.make(env_name, Options=Options, render_mode='human')

for ep in range(1):
    state, info = env.reset()
    done = False
    total_reward = 0
    steps = 0
    while not done:
        action = agent.act(state, add_noise=False)
        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        state = next_state
        total_reward += reward
        
    if info['collision']:
        ending_cause = "collision"
    elif info['out_of_bounds']:
        ending_cause = "out of bounds"
    elif info['time_limit']:
        ending_cause = "max steps reached"
    elif info['coverage'] == 100:
        ending_cause = "100% coverage"
    else:
        ending_cause = "unkown"
    print('total reward: ' + str(total_reward) + ' end episode for: ' + ending_cause)
env.close()
# Out:
# total reward: -4.67000000000008 end episode for: collision

# %%
env = gym.make(env_name, Options=Options)
yaws =[]
v_surges = []
v_sways = []
for ep in range(1):
    state, info = env.reset()
    agent.reset()
    done = False
    total_reward = 0
    steps = 0
    while not done:
        action = agent.act(state, add_noise=False)
        next_state, reward, terminated, truncated, info = env.step(action)
        yaws.append(action[2])
        v_surges.append(action[0])
        v_sways.append(action[1])
        done = terminated or truncated
        state = next_state
        total_reward += reward
        
    if info['collision']:
        ending_cause = "collision"
    elif info['out_of_bounds']:
        ending_cause = "out of bounds"
    elif info['time_limit']:
        ending_cause = "max steps reached"
    elif info['coverage'] == 100:
        ending_cause = "100% coverage"
    else:
        ending_cause = "unkown"
    print('total reward: ' + str(total_reward) + ' end episode for: ' + ending_cause)
env.close()
# Out:
# total reward: 142.1299999999998 end episode for: 100% coverage

# %%
plt.plot(yaws)
plt.show()
plt.plot(v_surges)
plt.show()
plt.plot(v_sways)
plt.show()

# %%
checkpoint = {
    'gamma' : gamma,
    'state_dim': state_dim,
    'action_dim': action_dim,
    'actor_lr': lr_actor,
    'critic_lr': lr_critic,
    'tau' : tau,
    'buffer_size' : buffer_size,
    'batch_size' : batch_size,
    'max_episodes' : max_episodes,
    'actor_state_dict': agent.actor.state_dict(),
    'total_rewards': total_rewards,
    'len_episodes' : len_episodes,
    'coverage_per_ep': coverage_per_ep,
    'Options' : Options,
    'env_name': env_name,
    'AC_version': 'AC_v3',
    'noise_type' : agent.noise_type,
    'desired_distance' : agent.desired_distance,
}

path = "ShipRovCont-v0/" + env_name + "_" + str(max_episodes) + "_ep_" + str(action_dim) + "_actions_AC_v3.0_param_noise.pth"
torch.save(checkpoint, path)
